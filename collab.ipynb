# %%
import pandas as pd

ratings = pd.read_csv('tmdb_5000_credits.csv')
movies = pd.read_csv('tmdb_5000_movies.csv')

ratings = pd.merge(movies,ratings)
ratings
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4804     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807          0                                                 []
# 4808          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
user_ratings =ratings.pivot_table(index=['id'],columns=['original_title'],values='vote_average')
user_ratings
# Out:
# original_title  #Horror  $upercapitalist  (500) Days of Summer  \
# id
# 5                   NaN              NaN                   NaN
# 11                  NaN              NaN                   NaN
# 12                  NaN              NaN                   NaN
# 13                  NaN              NaN                   NaN
# 14                  NaN              NaN                   NaN
# ...                 ...              ...                   ...
# 426067              NaN              NaN                   NaN
# 426469              NaN              NaN                   NaN
# 433715              NaN              NaN                   NaN
# 447027              NaN              NaN                   NaN
# 459488              NaN              NaN                   NaN
#
# original_title  ...E tu vivrai nel terrore! L'aldilà  10 Cloverfield Lane  \
# id
# 5                                                NaN                  NaN
# ...

# %%
###Drop all columns where less then 10 users rated them... to increase accuracy 
# user_ratings = user_ratings.dropna(thresh=10,axis=1).fillna(0)

user_ratings = user_ratings.fillna(0)
user_ratings
# Out:
# original_title  #Horror  $upercapitalist  (500) Days of Summer  \
# id
# 5                   0.0              0.0                   0.0
# 11                  0.0              0.0                   0.0
# 12                  0.0              0.0                   0.0
# 13                  0.0              0.0                   0.0
# 14                  0.0              0.0                   0.0
# ...                 ...              ...                   ...
# 426067              0.0              0.0                   0.0
# 426469              0.0              0.0                   0.0
# 433715              0.0              0.0                   0.0
# 447027              0.0              0.0                   0.0
# 459488              0.0              0.0                   0.0
#
# original_title  ...E tu vivrai nel terrore! L'aldilà  10 Cloverfield Lane  \
# id
# 5                                                0.0                  0.0
# ...

# %%
item_similarity_df = user_ratings.corr(method='pearson')
item_similarity_df.head(100)

# %%
def get_similar_movies(movie_name,user_rating):
    similar_score = item_similarity_df[movie_name]*(user_rating-5)
    similar_score = similar_score.sort_values(ascending=False)

    return similar_score

# %%
#TestData
action_ = {
           ("10 Days in a Madhouse",6),
           ("(500) Days of Summer",8.9),
           ("102 Dalmatians",8.7),
        }
similar_movies = pd.DataFrame()

for movie,rating in action_:
    similar_movies = similar_movies.append(get_similar_movies(movie,rating),ignore_index=True)

similar_movies.head()
z=similar_movies.sum().sort_values(ascending=False)
z
# Out:
# C:\Users\prajw\AppData\Local\Temp\ipykernel_11004\3931863205.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   similar_movies = similar_movies.append(get_similar_movies(movie,rating),ignore_index=True)
# C:\Users\prajw\AppData\Local\Temp\ipykernel_11004\3931863205.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   similar_movies = similar_movies.append(get_similar_movies(movie,rating),ignore_index=True)
# C:\Users\prajw\AppData\Local\Temp\ipykernel_11004\3931863205.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   similar_movies = similar_movies.append(get_similar_movies(movie,rating),ignore_index=True)
# original_title
# (500) Days of Summer     6.397980
# 102 Dalmatians           6.197938
# ...

# %%
import pickle
pickle.dump(z,open('movie_list1.pkl','wb'))
pickle.dump(similar_movies,open('similarity1.pkl','wb'))
